# %% [markdown]
# <a href="https://colab.research.google.com/github/trungepito/python-random-quote/blob/master/Testing_scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the testing of matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(2)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))

ax.set(xlim=(-4, 4), ylim=(-3, 3))

plt.show()

# %% [markdown]
# Testing scipy

# %%
from scipy.spatial import Delaunay
import numpy as np
points = np.array([[0, 0], [0, 1.1], [1, 0], [1, 1]])
tri = Delaunay(points)

# %%
plt.triplot(points[:,0], points[:,1], tri.simplices)
plt.plot(points[:,0], points[:,1], 'o')
for j, p in enumerate(points):
    plt.text(p[0]-0.03, p[1]+0.03, j, ha='right') # label the points
for j, s in enumerate(tri.simplices):
    p = points[s].mean(axis=0)
    plt.text(p[0], p[1], '#%d' % j, ha='center') # label triangles
plt.xlim(-0.5, 1.5); plt.ylim(-0.5, 1.5)
plt.show()

# %%
for j, p in enumerate(points):
    plt.text(p[0]-0.03, p[1]+0.03, j, ha='right') # label the points
for j, s in enumerate(tri.simplices):
    p = points[s].mean(axis=0)
    plt.text(p[0], p[1], '#%d' % j, ha='center') # label triangles
plt.xlim(-0.5, 1.5); plt.ylim(-0.5, 1.5)
plt.show()

# %%
import pandas as pd
df=pd.read_csv('abcd.csv',header=0)
df.head(6)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-e9511992c5ff> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('abcd.csv',header=0)
#       3 df.head(6)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='bin5', y='bin6', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
df.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Filename').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['Filename'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='bin10', y='Filename', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
print(df)
# Out:
#      Filename  bin1  bin2  bin3  bin4  bin5  bin6  bin7  bin8  bin9  ...  \
# 0  0.1064.bin     0     0   525  6901   947   401   235   166   123  ...
# 1   0.532.bin     0     0   270  6370  1067   496   276   137   121  ...
# 2   0.635.bin     0     0  2308  5997   586   296   151    89    71  ...
# 3   0.780.bin     0     0    17  5105  1547   732   487   282   219  ...
# 4   0.808.bin     0     0    71  5467  1321   733   453   305   229  ...
# 5   0.850.bin     0     0    43  5108  1479   790   485   227   224  ...
#
#    bin16  bin17  bin18  bin19  bin20  bin21  bin22  bin23  bin24  bin25
# 0     27     14     22     19     12     12     11     13      9    226
# 1     44     40     30     29     18     30     14     26     18    639
# 2     11     13     12     13     15      3     15      5     10    222
# 3     64     57     33     46     36     30     34     30     22    616
# 4     51     37     43     42     38     35     32     28     13    531
# ...

# %%
df2=pd.read_excel('abcd.xlsx',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-57d756bbcf82> in <cell line: 1>()
# ----> 1 df2=pd.read_excel('abcd.xlsx',index_col=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
